# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv("City_of_Seattle_Wages__Comparison_by_Gender_-_Discretionary_Pay_Titles_by_Department.csv")
test.head(50)
# Out:
#                         DEPARTMENT                      DESCR GENDER DESCR  \
# 0        Arts and Cultural Affairs                        NaN       Female
# 1        Arts and Cultural Affairs                        NaN         Male
# 2        Arts and Cultural Affairs            Total Employees          NaN
# 3        Arts and Cultural Affairs     Ave Yrs in Current Job          NaN
# 4                     City Auditor                        NaN       Female
# 5                     City Auditor                        NaN         Male
# 6                     City Auditor            Total Employees          NaN
# 7                     City Auditor     Ave Yrs in Current Job          NaN
# 8               City Budget Office                        NaN       Female
# 9               City Budget Office                        NaN         Male
# 10              City Budget Office            Total Employees          NaN
# ...

# %%
test.columns
# Out:
# Index(['DEPARTMENT', 'DESCR', 'GENDER DESCR', 'Admin Support # EE',
#        'Admin Support % Gender', 'Admin Support Avg Hrly',
#        'Admin Support Avg Yrs in Current Job', 'Officials/Admin # EE',
#        'Officials/Admin % Gender', 'Officials/Admin Avg Hrly',
#        'Officials/Admin Avg Yrs in Current Job', 'Para-Professionals # EE',
#        'Para-Professionals % Gender', 'Para-Professionals Avg Hrly',
#        'Para-Professionals Avg Yrs in Current Job', 'Professionals # EE',
#        'Professionals % Gender', 'Professionals Avg Hrly',
#        'Professionals Avg Yrs in Current Job', 'Protected Services # EE',
#        'Protected Services % Gender', 'Protected Services Avg Hrly',
#        'Protected Services Avg Yrs in Current Job', 'Service/Maintenance # EE',
#        'Service/Maintenance % Gender', 'Service/Maintenance Avg Hrly',
#        'Service/Maintenance Avg Yrs in Current Job', 'Skilled Craft # EE',
#        'Skilled Craft % Gender', 'Skilled Craft Avg Hrly',
# ...

# %%
selected_test = test[['DEPARTMENT', 'GENDER DESCR', 'Professionals Avg Hrly', 'Professionals Avg Yrs in Current Job', 'Technicians % Gender', 'Technicians Avg Hrly', 'Technicians Avg Yrs in Current Job']]
selected_test
# Out:
#                          DEPARTMENT GENDER DESCR  Professionals Avg Hrly  \
# 0         Arts and Cultural Affairs       Female                   35.00
# 1         Arts and Cultural Affairs         Male                   32.64
# 2         Arts and Cultural Affairs          NaN                     NaN
# 3         Arts and Cultural Affairs          NaN                     NaN
# 4                      City Auditor       Female                   49.67
# 5                      City Auditor         Male                   47.52
# 6                      City Auditor          NaN                     NaN
# 7                      City Auditor          NaN                     NaN
# 8                City Budget Office       Female                   45.60
# 9                City Budget Office         Male                   45.70
# 10               City Budget Office          NaN                     NaN
# 11               City Budget Office          NaN                     NaN
# ...
